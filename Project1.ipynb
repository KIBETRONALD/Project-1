# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('D:/Downloads/ames.csv')

# %%
df.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ...         ...      ...          ...      ...    ...   ...      ...
# 95   96          60       RL          NaN     9765   Pave   NaN      IR2
# 96   97          20       RL         78.0    10264   Pave   NaN      IR1
# 97   98          20       RL         73.0    10921   Pave   NaN      Reg
# 98   99          30       RL         85.0    10625   Pave   NaN      Reg
# 99  100          20       RL         77.0     9320   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 2          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 3          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 4          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# ..         ...       ...  ...      ...    ...   ...         ...     ...
# 95         Lvl    AllPub  ...        0    NaN   NaN        Shed     480
# 96         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 97         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 98         Lvl    AllPub  ...        0    NaN   NaN        Shed     400
# 99         Lvl    AllPub  ...        0    NaN   NaN        Shed     400
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       2   2008        WD         Normal     208500
# 1       5   2007        WD         Normal     181500
# 2       9   2008        WD         Normal     223500
# 3       2   2006        WD        Abnorml     140000
# 4      12   2008        WD         Normal     250000
# ..    ...    ...       ...            ...        ...
# 95      4   2009        WD         Normal     185000
# 96      8   2006        WD         Normal     214000
# 97      5   2007        WD         Normal      94750
# 98      5   2010       COD        Abnorml      83000
# 99      1   2010        WD         Normal     128950
#
# [100 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df1 = df[['OverallCond', 'SalePrice']]

# %%
df1['OverallCond'] = df1['OverallCond'].astype('int')
df1['SalePrice'] = df1['SalePrice'].astype('int')
# Out:
# <ipython-input-24-9ec5d1eaf3e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['OverallCond'] = df1['OverallCond'].astype('int')
# <ipython-input-24-9ec5d1eaf3e6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['SalePrice'] = df1['SalePrice'].astype('int')

# %%
df1.head()
# Out:
#    OverallCond  SalePrice
# 0            5     208500
# 1            8     181500
# 2            5     223500
# 3            5     140000
# 4            5     250000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallCond  1460 non-null   int32
#  1   SalePrice    1460 non-null   int32
# dtypes: int32(2)
# memory usage: 11.5 KB

# %%
df1.columns
# Out:
# Index(['OverallCond', 'SalePrice'], dtype='object')

# %%
df2=df1.groupby('OverallCond')[['SalePrice']].sum()

# %%
df2
# Out:
#              SalePrice
# OverallCond
# 1                61000
# 2               709932
# 3              2548235
# 4              6864991
# 5            166783617
# 6             38798321
# 7             32419825
# 8             11206925
# 9              4752100

# %%
import matplotlib.pyplot as plt

Ova_saleprice = df1[['OverallCond', 'SalePrice']]

Total_salesprice = {}
for i in Ova_saleprice['OverallCond'].unique():
    condition_values = Ova_saleprice.loc[Ova_saleprice['OverallCond'] == i, 'SalePrice'].tolist()
    Total_salesprice[i] = sum(condition_values)

sale_price = Total_salesprice.items()
Sorted_salesprice = sorted(sale_price, key=lambda x: x[0])
x = [item[0] for item in Sorted_salesprice]
y = [item[1] for item in Sorted_salesprice]

# plotting a bar plot for quantity against sales
fig, ax = plt.subplots()
bars = ax.bar(x, y)
ax.set_ylabel('Total salesprice')
ax.set_xlabel('Overallcond')
ax.set_title('Salesprice distribution per Overallcond')

# Display values on top of each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
#Separate the data into subsets based on OverallCond, then demonstrate how this split impacts the distribution of SalePrice.
# Assuming df1 is your DataFrame
Ova_saleprice = df1[['OverallCond', 'SalePrice']]

Total_salesprice = {}
for i in Ova_saleprice['OverallCond'].unique():
    condition_values = Ova_saleprice.loc[Ova_saleprice['OverallCond'] == i, 'SalePrice'].tolist()
    Total_salesprice[i] = sum(condition_values)

sale_price = Total_salesprice.items()
Sorted_salesprice = sorted(sale_price, key=lambda x: x[0])
x = [item[0] for item in Sorted_salesprice]
y = [item[1] for item in Sorted_salesprice]

# plotting a horizontal bar plot for quantity against sales
fig, ax = plt.subplots()
bars = ax.barh(x, y)  # Use barh instead of bar
ax.set_xlabel('Total salesprice')
ax.set_ylabel('Overallcond')
ax.set_title('Salesprice distribution per Overallcond')

# Display values on the right of each bar
for bar in bars:
    xval = bar.get_width()
    plt.text(xval, bar.get_y() + bar.get_height()/2, round(xval, 2), ha='left', va='center')

# Adjust y-axis and x-axis limits for horizontal bar plot
#ax.set_ylim(min(x) - 0.5, max(x) + 0.1)  # You can adjust the margins as needed
ax.set_xlim(0, max(y) + 10000)  # You can adjust the upper limit of x-axis as needed

plt.show()

# %%
#Produce summary statistics, visualizations, and interpretive text describing the distributions of SalePrice, TotRmsAbvGrd, and OverallCond.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Extract the relevant columns
selected_columns = ['SalePrice', 'TotRmsAbvGrd', 'OverallCond']
selected_data = df[selected_columns]

# Summary Statistics
summary_statistics = selected_data.describe().T

# Visualizations
# Histograms for SalePrice, TotRmsAbvGrd
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))

selected_data['SalePrice'].plot(kind='hist', bins=20, ax=axes[0, 0], edgecolor='black')
axes[0, 0].set_title('Distribution of SalePrice')
axes[0, 0].set_xlabel('SalePrice')

selected_data['TotRmsAbvGrd'].plot(kind='hist', bins=10, ax=axes[0, 1], edgecolor='black')
axes[0, 1].set_title('Distribution of TotRmsAbvGrd')
axes[0, 1].set_xlabel('TotRmsAbvGrd')

# Boxplot for OverallCond
selected_data.boxplot(column='OverallCond', ax=axes[1, 0])
axes[1, 0].set_title('Boxplot of OverallCond')

# Scatter plot of TotRmsAbvGrd vs SalePrice
axes[1, 1].scatter(selected_data['TotRmsAbvGrd'], selected_data['SalePrice'], alpha=0.5)
axes[1, 1].set_title('Scatter plot of TotRmsAbvGrd vs SalePrice')
axes[1, 1].set_xlabel('TotRmsAbvGrd')
axes[1, 1].set_ylabel('SalePrice')

plt.tight_layout()
plt.show()

# Interpretive Text
print("Summary Statistics:")
print(summary_statistics)

print("\nInterpretation:")
print("1. SalePrice Distribution: The histogram shows the distribution of SalePrice. It appears to be right-skewed.")
print("2. TotRmsAbvGrd Distribution: The histogram shows the distribution of TotRmsAbvGrd.")
print("3. OverallCond Boxplot: The boxplot displays the distribution of OverallCond. Outliers may be present below the lower whisker.")
print("4. Scatter plot: The scatter plot depicts the relationship between TotRmsAbvGrd and SalePrice.")
# Out:
# Summary Statistics:
#                count           mean           std      min       25%  \
# SalePrice     1460.0  180921.195890  79442.502883  34900.0  129975.0
# TotRmsAbvGrd  1460.0       6.517808      1.625393      2.0       5.0
# OverallCond   1460.0       5.575342      1.112799      1.0       5.0
#
#                    50%       75%       max
# SalePrice     163000.0  214000.0  755000.0
# TotRmsAbvGrd       6.0       7.0      14.0
# OverallCond        5.0       6.0       9.0
#
# Interpretation:
# 1. SalePrice Distribution: The histogram shows the distribution of SalePrice. It appears to be right-skewed.
# 2. TotRmsAbvGrd Distribution: The histogram shows the distribution of TotRmsAbvGrd.
# 3. OverallCond Boxplot: The boxplot displays the distribution of OverallCond. Outliers may be present below the lower whisker.
# 4. Scatter plot: The scatter plot depicts the relationship between TotRmsAbvGrd and SalePrice.

# %%
df3=df.groupby('TotRmsAbvGrd')[['SalePrice']].sum()

# %%
df3
# Out:
#               SalePrice
# TotRmsAbvGrd
# 2                 39300
# 3               1890700
# 4              11915929
# 5              38926456
# 6              64843925
# 7              64703372
# 8              39910948
# 9              18974113
# 10             13925121
# 11              5724396
# 12              3090686
# 14               200000

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#Create a new feature Age, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.
# Assuming df is your DataFrame
# Create a new feature 'Age'
df['Age'] = df['YrSold'] - df['YearBuilt']

# Plot the relationship between 'Age' and 'SalePrice'
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['SalePrice'], alpha=0.5)
plt.title('Relationship between Age and SalePrice')
plt.xlabel('Age (Years)')
plt.ylabel('SalePrice')
plt.show()

# %%
#Find the features that have the strongest positive and negative correlations with SalePrice, and produce plots representing these relationships.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_data = df.corr()
strongest_pos_corr_saleprice = correlation_data['SalePrice'].sort_values(ascending=False).head(5)
strongest_corr_neg_saleprice = correlation_data['SalePrice'].sort_values(ascending=True).head(5)

plt.figure(figsize=(40, 20))
sns.heatmap(correlation_data, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f", square=True)

plt.title('Variables correlation with the saleprice')
plt.xticks(rotation=45)
plt.yticks(rotation=45)

plt.tight_layout()
print('Strongest +ve Corr:)
print(strongest_pos_corr_saleprice)
print('Strong negative corr:')
plt.show()
